# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
imdb_df = pd.read_csv("new_cleaned.csv")

# %%
imdb_df.head()
# Out:
#   released_year certificate  runtime                 genre  imdb_rating  \
# 0          1994           A      142                 Drama          9.3
# 1          1972           A      175          Crime, Drama          9.2
# 2          2008          UA      152  Action, Crime, Drama          9.0
# 3          1974           A      202          Crime, Drama          9.0
# 4          1957           U       96          Crime, Drama          9.0
#
#    meta_score              director           star1           star2  \
# 0        80.0        Frank Darabont     Tim Robbins  Morgan Freeman
# 1       100.0  Francis Ford Coppola   Marlon Brando       Al Pacino
# 2        84.0     Christopher Nolan  Christian Bale    Heath Ledger
# 3        90.0  Francis Ford Coppola       Al Pacino  Robert De Niro
# 4        96.0          Sidney Lumet     Henry Fonda     Lee J. Cobb
#
#            star3           star4  no_of_votes        gross
# 0     Bob Gunton  William Sadler      2343110   28341469.0
# ...

# %%
# Categorize counts
def categorize_count(count):
    if  count==1 :
        return 'low'
    elif 2<= count <= 3:
        return 'average'
    else:
        return 'high'

# %% [markdown]
# ## Director categorization

# %%
# Calculate value counts
director_counts = imdb_df['director'].value_counts().reset_index()
director_counts.columns = ['director', 'count']
director_counts
# Out:
#                  director  count
# 0        Steven Spielberg     13
# 1         Martin Scorsese     10
# 2        Alfred Hitchcock      9
# 3       Christopher Nolan      8
# 4          Clint Eastwood      8
# ..                    ...    ...
# 397           Jon Favreau      1
# 398           Yimou Zhang      1
# 399         Danis Tanovic      1
# 400  Shin'ichirô Watanabe      1
# 401        Richard Lester      1
#
# [402 rows x 2 columns]

# %%
# Apply categorization
director_counts['director_category'] = star1_counts['count'].apply(categorize_count)

# Merge the director_counts counts back to the original DataFrame
imdb_df = imdb_df.merge(director_counts[['director', 'director_category']], on='director', how='left')

# Create DataFrames for each category
director_group_1 = imdb_df[imdb_df['director_category'] == 'low']
director_group_2_3 = imdb_df[imdb_df['director_category'] == 'average']
director_group_4_plus = imdb_df[imdb_df['director_category'] == 'high']

# print the DataFrames
print("Director 1 with 1 movies:")
display(director_group_1.head())

print("\nDirectors with 2-3 movies:")
display(director_group_2_3.head())

print("\nDirectors with 4 or more movies:")
display(director_group_4_plus.head())
# Out:
# Director 1 with 1 movies:
#    released_year certificate  runtime                       genre  \
# 14          1999           A      136              Action, Sci-Fi
# 16          1980          UA      124  Action, Adventure, Fantasy
# 17          1975           A      133                       Drama
# 20          2002           A      130                Crime, Drama
# 24          1997           U      116      Comedy, Drama, Romance
#
#     imdb_rating  meta_score            director            star1  \
# 14          8.7        73.0      Lana Wachowski  Lilly Wachowski
# 16          8.7        82.0      Irvin Kershner      Mark Hamill
# 17          8.7        83.0        Milos Forman   Jack Nicholson
# 20          8.6        79.0  Fernando Meirelles       Kátia Lund
# 24          8.6        59.0     Roberto Benigni  Roberto Benigni
#
#                   star2               star3                 star4  \
# 14         Keanu Reeves  Laurence Fishburne      Carrie-Anne Moss
# ...

# %%
imdb_df.director_category.value_counts()
# Out:
# director_category
# low        310
# average    241
# high       163
# Name: count, dtype: int64

# %% [markdown]
# ## Star 1 categorization

# %%
# Calculate value counts
star1_counts = imdb_df['star1'].value_counts().reset_index()
star1_counts.columns = ['star1', 'count']
star1_counts
# Out:
#                     star1  count
# 0               Tom Hanks     12
# 1               Al Pacino     10
# 2          Robert De Niro     10
# 3          Clint Eastwood     10
# 4       Leonardo DiCaprio      9
# ..                    ...    ...
# 467  Marcello Mastroianni      1
# 468           Omar Sharif      1
# 469                 Topol      1
# 470       Timothy Bottoms      1
# 471        Burt Lancaster      1
#
# [472 rows x 2 columns]

# %%
# Apply categorization
star1_counts['star1_category'] = star1_counts['count'].apply(categorize_count)

# Merge the star1_counts counts back to the original DataFrame
imdb_df = imdb_df.merge(star1_counts[['star1', 'star1_category']], on='star1', how='left')

# Create DataFrames for each category
star1_group_1 = imdb_df[imdb_df['star1_category'] == 'low']
star1_group_2_3 = imdb_df[imdb_df['star1_category'] == 'average']
star1_group_4_plus = imdb_df[imdb_df['star1_category'] == 'high']

# print the DataFrames
print("Star 1 with 1 movies:")
display(star1_group_1.head())

print("\nStar 1 with 2_3 movies:")
display(star1_group_2_3.head())

print("\nStar 1 with 4 or more movies:")
display(star1_group_4_plus.head())
# Out:
# Star 1 with 1 movies:
#    released_year certificate  runtime                         genre  \
# 0           1994           A      142                         Drama
# 6           1994           A      154                  Crime, Drama
# 14          1999           A      136                Action, Sci-Fi
# 20          2002           A      130                  Crime, Drama
# 21          2001           U      125  Animation, Adventure, Family
#
#     imdb_rating  meta_score            director            star1  \
# 0           9.3        80.0      Frank Darabont      Tim Robbins
# 6           8.9        94.0   Quentin Tarantino    John Travolta
# 14          8.7        73.0      Lana Wachowski  Lilly Wachowski
# 20          8.6        79.0  Fernando Meirelles       Kátia Lund
# 21          8.6        96.0      Hayao Miyazaki    Daveigh Chase
#
#                   star2               star3                 star4  \
# 0        Morgan Freeman          Bob Gunton        William Sadler
# ...

# %%
imdb_df.star1_category.value_counts()
# Out:
# star1_category
# low        356
# average    202
# high       156
# Name: count, dtype: int64

# %% [markdown]
# ## Star 2 categorization

# %%
# Calculate value counts
star2_counts = imdb_df['star2'].value_counts().reset_index()
star2_counts.columns = ['star2', 'count']
star2_counts
# Out:
#                 star2  count
# 0         Emma Watson      7
# 1          Matt Damon      5
# 2        Kate Winslet      4
# 3         Julie Delpy      4
# 4           Brad Pitt      4
# ..                ...    ...
# 594   Mathieu Amalric      1
# 595  Robert Rodriguez      1
# 596           Hee Jae      1
# 597     Edgar Ramírez      1
# 598  Montgomery Clift      1
#
# [599 rows x 2 columns]

# %%
# Apply categorization
star2_counts['star2_category'] = star2_counts['count'].apply(categorize_count)

# Merge the star1_counts counts back to the original DataFrame
imdb_df = imdb_df.merge(star2_counts[['star2', 'star2_category']], on='star2', how='left')

# Create DataFrames for each category
star2_group_1 = imdb_df[imdb_df['star2_category'] == 'low']
star2_group_2_3 = imdb_df[imdb_df['star2_category'] == 'average']
star2_group_4_plus = imdb_df[imdb_df['star2_category'] == 'high']

# print the DataFrames
print("Star 2 with 1 movies:")
display(star2_group_1.head())

print("\nStar 2 with 2_3 movies:")
display(star2_group_2_3.head())

print("\nStar 2 with 4 plus movies:")
display(star2_group_4_plus.head())
# Out:
# Star 2 with 1 movies:
#    released_year certificate  runtime                      genre  imdb_rating  \
# 0           1994           A      142                      Drama          9.3
# 4           1957           U       96               Crime, Drama          9.0
# 7           1993           A      195  Biography, Drama, History          8.9
# 9           1999           A      139                      Drama          8.8
# 12          1966           A      161                    Western          8.8
#
#     meta_score          director           star1           star2  \
# 0         80.0    Frank Darabont     Tim Robbins  Morgan Freeman
# 4         96.0      Sidney Lumet     Henry Fonda     Lee J. Cobb
# 7         94.0  Steven Spielberg     Liam Neeson   Ralph Fiennes
# 9         66.0     David Fincher       Brad Pitt   Edward Norton
# 12        90.0      Sergio Leone  Clint Eastwood     Eli Wallach
#
#             star3             star4  no_of_votes       gross  \
# ...

# %%
imdb_df.star2_category.value_counts()
# Out:
# star2_category
# low        522
# average    152
# high        40
# Name: count, dtype: int64

# %% [markdown]
# ## Star 3 categorization

# %%
# Calculate value counts
star3_counts = imdb_df['star3'].value_counts().reset_index()
star3_counts.columns = ['star3', 'count']
star3_counts
# Out:
#                  star3  count
# 0         Rupert Grint      5
# 1            Joe Pesci      4
# 2       Rachel McAdams      4
# 3    Jennifer Connelly      4
# 4    Samuel L. Jackson      4
# ..                 ...    ...
# 621        Lola Dueñas      1
# 622       Craig Bierko      1
# 623      Saif Ali Khan      1
# 624       Billy Crudup      1
# 625       Deborah Kerr      1
#
# [626 rows x 2 columns]

# %%
# Apply categorization
star3_counts['star3_category'] = star3_counts['count'].apply(categorize_count)

# Merge the star1_counts counts back to the original DataFrame
imdb_df = imdb_df.merge(star3_counts[['star3', 'star3_category']], on='star3', how='left')

# Create DataFrames for each category
star3_group_1 = imdb_df[imdb_df['star3_category'] == 'low']
star3_group_2_3 = imdb_df[imdb_df['star3_category'] == 'average']
star3_group_4_plus = imdb_df[imdb_df['star3_category'] == 'high']

# print the DataFrames
print("Star 3 with 1 movies:")
display(star3_group_1.head())

print("Star 3 with 2_3 movies:")
display(star3_group_2_3.head())

print("Star 3 with 4 plus movies:")
display(star3_group_4_plus.head())
# Out:
# Star 3 with 1 movies:
#   released_year certificate  runtime                     genre  imdb_rating  \
# 0          1994           A      142                     Drama          9.3
# 1          1972           A      175              Crime, Drama          9.2
# 2          2008          UA      152      Action, Crime, Drama          9.0
# 4          1957           U       96              Crime, Drama          9.0
# 5          2003           U      201  Action, Adventure, Drama          8.9
#
#    meta_score              director           star1            star2  \
# 0        80.0        Frank Darabont     Tim Robbins   Morgan Freeman
# 1       100.0  Francis Ford Coppola   Marlon Brando        Al Pacino
# 2        84.0     Christopher Nolan  Christian Bale     Heath Ledger
# 4        96.0          Sidney Lumet     Henry Fonda      Lee J. Cobb
# 5        94.0         Peter Jackson     Elijah Wood  Viggo Mortensen
#
# ...

# %%
imdb_df.star3_category.value_counts()
# Out:
# star3_category
# low        562
# average    119
# high        33
# Name: count, dtype: int64

# %% [markdown]
# ## Star 4 categorization

# %%
# Calculate value counts
star4_counts = imdb_df['star4'].value_counts().reset_index()
star4_counts.columns = ['star4', 'count']
star4_counts
# Out:
#                       star4  count
# 0             Michael Caine      4
# 1              Mark Ruffalo      3
# 2          Catherine Keener      3
# 3         Stellan Skarsgård      2
# 4               Kevin Bacon      2
# ..                      ...    ...
# 666  Anthony Chau-Sang Wong      1
# 667         Keira Knightley      1
# 668           Jessica Lange      1
# 669               Jason Lee      1
# 670              Donna Reed      1
#
# [671 rows x 2 columns]

# %%
# Apply categorization
star4_counts['star4_category'] = star4_counts['count'].apply(categorize_count)

# Merge the star1_counts counts back to the original DataFrame
imdb_df = imdb_df.merge(star4_counts[['star4', 'star4_category']], on='star4', how='left')

# Create DataFrames for each category
star4_group_1 = imdb_df[imdb_df['star4_category'] == 'low']
star4_group_2_3 = imdb_df[imdb_df['star4_category'] == 'average']
star4_group_4_plus = imdb_df[imdb_df['star4_category'] == 'high']

# print the DataFrames
print("Star 4 with 1 movies:")
display(star4_group_1.head())

print("Star 4 with 2_3 movies:")
display(star4_group_2_3.head())

print("Star 4 with 4 plu movies:")
display(star4_group_4_plus.head())
# Out:
# Star 4 with 1 movies:
#   released_year certificate  runtime                      genre  imdb_rating  \
# 0          1994           A      142                      Drama          9.3
# 4          1957           U       96               Crime, Drama          9.0
# 6          1994           A      154               Crime, Drama          8.9
# 7          1993           A      195  Biography, Drama, History          8.9
# 8          2010          UA      148  Action, Adventure, Sci-Fi          8.8
#
#    meta_score           director              star1                 star2  \
# 0        80.0     Frank Darabont        Tim Robbins        Morgan Freeman
# 4        96.0       Sidney Lumet        Henry Fonda           Lee J. Cobb
# 6        94.0  Quentin Tarantino      John Travolta           Uma Thurman
# 7        94.0   Steven Spielberg        Liam Neeson         Ralph Fiennes
# 8        74.0  Christopher Nolan  Leonardo DiCaprio  Joseph Gordon-Levitt
#
# ...

# %%
imdb_df.star4_category.value_counts()
# Out:
# star4_category
# low        632
# average     78
# high         4
# Name: count, dtype: int64

# %% [markdown]
# ## Cleaned CSV

# %%
imdb_df.to_csv('director_star_grouping_cleaned.csv',index=False)
